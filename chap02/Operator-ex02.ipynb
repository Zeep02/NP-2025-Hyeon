# %% [markdown]
# ### 2장 연습문제 - 논리 연산자
# **학과**|**컴퓨터공학과**
# :----:|:-----
# **학번**|**202311423**
# **이름**|**Yun DongHyeon**
# **날짜**|**2025-09-10**

# %% [markdown]
# * 연습문제 1. 5가 3보다 크고 7보다 작은지 검사하는 프로그램을 작성하라.

# %%
5 > 3 and 5 < 7
# Out:
# True

# %% [markdown]
# * 연습문제 2. 변수 x가 10 이상이고 20 이하인지 검사하는 프로그램을 작성하라.

# %%
x = int(input("수 입력: "))
x > 10 and x < 20
# Out:
# True

# %% [markdown]
# * 연습문제 3. 변수 y가 5의 배수이거나 7의 배수인지 검사하는 프로그램을 작성하라.

# %%
y = int(input("수 입력: "))
y % 5 == 0 or y % 7 == 0
# Out:
# True

# %% [markdown]
# * 연습문제 4. 변수 z가 양수이면서 짝수인지 검사하는 프로그램을 작성하라.

# %%
z = int(input("수 입력: "))
z % 2 == 0 and x >= 0
# Out:
# True

# %% [markdown]
# * 연습문제 5. 변수 a가 문자열 "hello"나 문자열 "world" 중 하나인지 검사하는 프로그램을 작성하라.

# %%
a = input(": ")
a == "hello" or a == "world"
# Out:
# True
