# %% [markdown]
# ### 2장 연습문제
# **학과**|**컴퓨터공학과**
# :----:|:-----
# **학번**|**202311423**
# **이름**|**Yun DongHyeon**
# **날짜**|**2025-09-10**

# %% [markdown]
# * 연습문제 1. 5와 3을 더한 값을 출력하는 프로그램을 작성하라.

# %%
print(f"5 + 3 = {5+3}")
# Out:
# 5 + 3 = 8

# %% [markdown]
# * 연습문제 2. 7에서 3을 뺀 값을 출력하는 프로그램을 작성하라.

# %%
print(f"7 - 3 = {7-3}")
# Out:
# 7 - 3 = 4

# %% [markdown]
# * 연습문제 3. 4를 2로 나눈 값을 출력하는 프로그램을 작성하라.

# %%
print(f"4 / 2 = {4/2}")
# Out:
# 4 / 2 = 2.0

# %% [markdown]
# * 연습문제 4. 8을 3으로 나눈 몫과 나머지를 출력하는 프로그램을 작성하라.

# %%
print(f"8 / 3 = {8//3}, {8%3}")
# Out:
# 8 / 3 = 2, 2

# %% [markdown]
# * 연습문제 5. 2의 5제곱을 출력하는 프로그램을 작성하라.

# %%
print(f"2의 5승: {2**5}")
# Out:
# 2의 5승: 32

# %% [markdown]
# * 연습문제 6. 입력된 정수가 10보다 크고 20보다 작은지 검사하는 프로그램을 작성하라.

# %%
x = int(input("수 입력(정수): "))
if x > 10 and x < 20:
    print("입력된 수는 10보다 크고 20보다 작습니다.")
else:
    print("ERROR")
# Out:
# ERROR

# %% [markdown]
# * 연습문제 7. 문자열 "hello"와 문자열 "world"를 이어 붙인 결과를 출력하는 프로그램을 작성하라.

# %%
x = "hello"
y = "world"
print(x+y)
# Out:
# helloworld

# %% [markdown]
# * 연습문제 8. 7을 2로 나눈 결과가 3보다 작은지 검사하는 프로그램을 작성하라

# %%
x = 7
y = 2
if (x / 7) < 3:
    print("True")
else:
    print("False")
# Out:
# True

# %% [markdown]
# * 연습문제 9. 변수 x의 값이 5와 같지 않은지 검사하는 프로그램을 작성하라.

# %%
x = 5
print(x==5)
# Out:
# True

# %% [markdown]
# * 연습문제 10. 변수 y의 값이 10에서 20 사이의 값인지 검사하는 프로그램을 작성하라.

# %%
y = int(input("수: "))
print("True" if y > 10 and y < 20 else "False")
# Out:
# False
